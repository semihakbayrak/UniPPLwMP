# %%
using Random, LargeMessageCollider, Flux.Optimise, Distributions, Plots
# Out:
# ┌ Info: Precompiling LargeMessageCollider [7f03d5f0-357e-4842-abc9-7001c0bc8a0e]
# └ @ Base loading.jl:1278
# ┌ Warning: Package LargeMessageCollider does not have Random in its dependencies:
# │ - If you have LargeMessageCollider checked out for development and have
# │   added Random as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with LargeMessageCollider
# └ Loading Random into LargeMessageCollider from project dependency, future warnings for LargeMessageCollider are suppressed.

# %%
Random.seed!(123);

# %%
# Synthetic Data
N = 4
inputs = [-5., -0.2, 15., 6.]
perturbations = rand(Normal(0,2),N)
sensor_inputs = inputs .+ perturbations
sensor_outputs = zeros(N)
for n=1:N
    sensor_outputs[n] = rand(TruncatedNormal(sensor_inputs[n], 0.5, 0., 10.))
end

# %%
sensor_inputs
# Out:
# 4-element Array{Float64,1}:
#  -2.6194642380274464
#   3.8963594155784795
#  17.2853018057344
#   6.918831240814161

# %%
sensor_outputs
# Out:
# 4-element Array{Float64,1}:
#  0.06914555476797446
#  4.386843328957746
#  9.993014452853238
#  6.8217167072613005

# %%
# initial messages
w_forw = Gamma(5,1) # Prior for w
x_back = [] # Initial backward messages from f_x
for n=1:N
    push!(x_back,Gamma(0.01,100))
end

# %%
# Inference
q_x = []
q_w = w_forw
for iter=1:10
    # Inference for x
    for i=1:N
        # Calculate the message towards fx_i
        m_fx = w_forw
        for n=1:N
            if n != i
                m_fx = collide(m_fx,x_back[n])
            end
        end
        # Calculate the forward message towards x_i
        mx_forw = normal(nothing,inputs[i],m_fx)
        if iter == 1 push!(q_x,mx_forw) end
        log_mx_back(x) = logpdf(TruncatedNormal(x, 0.5, 0., 10.),sensor_outputs[i])
        # Stochastic optimization
        gradOpt = FEgradient(ADAM(),1000)
        q_x[i] = approximateMarginal!(gradOpt, q_x[i], log_mx_back, mx_forw)
        x_back[i] = normal(q_x[i],inputs[i],nothing)
    end
    # Inference for w
    q_w = w_forw
    for n=1:N
        q_w = collide(q_w,x_back[n])
    end
end

# %%
q_x
# Out:
# 4-element Array{Any,1}:
#  Student(μ=-4.966855939427781, σ=0.6749010440892785, ν=5.441560553552792)
#  Student(μ=4.142854475963698, σ=0.43010264024333267, ν=7.008663306093868)
#  Student(μ=15.11156805213092, σ=0.7537081773206094, ν=10.615881626811227)
#  Student(μ=6.580260646628636, σ=0.3700944794492979, ν=13.302864412947187)

# %%
q_w
# Out:
# Gamma{Float64}(α=7.0, θ=0.08676477024992262)

# %%
mean(q_w)
# Out:
# 0.6073533917494583

# %%
sensor_inputs
# Out:
# 4-element Array{Float64,1}:
#  -2.6194642380274464
#   3.8963594155784795
#  17.2853018057344
#   6.918831240814161

# %%
x_ax = collect(-20:0.01:20)
plot(x_ax,pdf.(q_x[1],x_ax), lw=2, label="Approximate marginal")
scatter!((sensor_inputs[1],0), label="Perturbated input")

# %%
x_ax = collect(-20:0.01:20)
plot(x_ax,pdf.(q_x[2],x_ax), lw=2, label="Approximate marginal")
scatter!((sensor_inputs[2],0), label="Perturbated input", legend=:topleft)

# %%
x_ax = collect(-20:0.01:20)
plot(x_ax,pdf.(q_x[3],x_ax), lw=2, label="Approximate marginal")
scatter!((sensor_inputs[3],0), label="Perturbated input", legend=:topleft)

# %%
x_ax = collect(-20:0.01:20)
plot(x_ax,pdf.(q_x[4],x_ax), lw=2, label="Approximate marginal")
scatter!((sensor_inputs[4],0), label="Perturbated input", legend=:topleft)

# %%
x_ax = collect(-20:0.01:20)
p1 = plot(x_ax,pdf.(q_x[1],x_ax), lw=2, label=false, color=:black)
scatter!((sensor_inputs[1],0), markersize=8, label=false, color=:black)
p2 = plot(x_ax,pdf.(q_x[2],x_ax), lw=2, label=false, color=:black)
scatter!((sensor_inputs[2],0), markersize=8, label=false, color=:black)
p3 = plot(x_ax,pdf.(q_x[3],x_ax), lw=2, label=false, color=:black)
scatter!((sensor_inputs[3],0), markersize=8, label=false, color=:black)
p4 = plot(x_ax,pdf.(q_x[4],x_ax), lw=2, label=false, color=:black)
scatter!((sensor_inputs[4],0), markersize=8, label=false, color=:black)
p_all = plot(p1,p2,p3,p4, layout=(2,2), size = (900, 500))

# %%
savefig(p_all, "StudentApproximations.pdf")
