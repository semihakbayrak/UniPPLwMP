# %%
using Random, LargeMessageCollider, Flux.Optimise, Distributions, Plots
# Out:
# ┌ Info: Precompiling LargeMessageCollider [7f03d5f0-357e-4842-abc9-7001c0bc8a0e]
# └ @ Base loading.jl:1278
# ┌ Warning: Package LargeMessageCollider does not have Random in its dependencies:
# │ - If you have LargeMessageCollider checked out for development and have
# │   added Random as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with LargeMessageCollider
# └ Loading Random into LargeMessageCollider from project dependency, future warnings for LargeMessageCollider are suppressed.

# %%
Random.seed!(123);
N = 5;

# %%
inputs = [-5., -0.2, 3., 15., 6.]
# Out:
# 5-element Array{Float64,1}:
#  -5.0
#  -0.2
#   3.0
#  15.0
#   6.0

# %%
perturbations = rand(Normal(0,2),N)
# Out:
# 5-element Array{Float64,1}:
#   2.3805357619725536
#   4.09635941557848
#   2.285301805734398
#   0.9188312408141607
#  -0.793358158590446

# %%
sensor_inputs = inputs .+ perturbations
# Out:
# 5-element Array{Float64,1}:
#  -2.6194642380274464
#   3.8963594155784795
#   5.285301805734398
#  15.91883124081416
#   5.206641841409554

# %%
sensor_outputs = zeros(N)
for n=1:N
    sensor_outputs[n] = rand(truncated(Normal(sensor_inputs[n],0.5), 0., 10.))
end

# %%
sensor_outputs
# Out:
# 5-element Array{Float64,1}:
#  0.08531119988226044
#  3.8586178823796016
#  5.422209491340476
#  9.995321137672626
#  4.784702880686019

# %%
# initial messages
w_forw = Gamma(5,1) # Prior for w
x_back = [] # Initial backward messages from f_x
for n=1:N
    push!(x_back,Gamma(0.01,100))
end

# %%
m_fx = w_forw
for n=1:N
    m_fx = collide(m_fx,x_back[n])
end

# %%
m_fx
# Out:
# Gamma{Float64}(α=0.04999999999999938, θ=0.9523809523809523)

# %%
# Inference
evmp = EVMP(100)
q_x = []
q_w = w_forw
for iter=1:10
    # Inference for x
    for i=1:N
        # Calculate the message towards fx_i
        m_fx = w_forw
        for n=1:N
            if n != i
                m_fx = collide(m_fx,x_back[n])
            end
        end
        # Calculate the forward message towards x_i
        mx_forw = normal(nothing,inputs[i],m_fx)
        if iter == 1 push!(q_x,mx_forw) end
        log_mx_back(x) = logpdf(truncated(Normal(x,0.5), 0., 10.),sensor_outputs[i])
        # EVMP
        q_x[i] = approximateMarginal!(evmp,nothing,log_mx_back,mx_forw)
        x_back[i] = normal(q_x[i],inputs[i],nothing)
    end
    # Inference for w
    q_w = w_forw
    for n=1:N
        q_w = collide(q_w,x_back[n])
    end
end

# %%
q_x
# Out:
# 5-element Array{Any,1}:
#  SampleList(
# samples: Any[-5.804009268837148, -5.176772436510544, -4.57992609697494, -4.2584084223140275, -5.284639979559843, -3.5296421259237976, -4.176326813897154, -4.995527308955106, -6.382348048388666, -4.896970319655386  …  -5.142963682808979, -4.519076187512758, -3.5390514954349337, -4.786817639666585, -4.383879052855773, -4.040382259666165, -4.347543747725283, -3.132919197815732, -3.7877170024352442, -3.255147158884112]
# weights: [0.010142142010279988, 0.008948346990166304, 0.009381421002959946, 0.010215824337954014, 0.00903890275689918, 0.010245484221574955, 0.010369937585263837, 0.011632438645299208, 0.008305490496825997, 0.009750234351902117  …  0.0076069522968088, 0.006673773711477271, 0.01004183865669126, 0.012066542314453442, 0.009056029050834599, 0.008611810908208612, 0.00848627947300619, 0.011547542313626357, 0.009624423135841016, 0.0109295175836336]
# num_samples: 100
# dimension: 1
# )
#
#  SampleList(
# samples: Any[7.003677811217466, 4.9174409724333525, 7.6442629778703965, 6.012697931668978, 3.9689234879492563, 5.47155471465428, 5.415286240098311, 6.113254911650977, 4.543545349893986, 6.150343081557528  …  6.154774681503861, 6.476591522511995, 6.986362447303276, 5.733532718076711, 7.167581929539351, 6.348604773514715, 4.8840165638900395, 6.900141730928444, 7.925324011730781, 4.731040781901892]
# weights: [2.5294234571980517e-6, 0.04618692719401244, 3.778320080444428e-9, 0.0023443118587392914, 0.012640975528794335, 0.018623136679894688, 0.02159938522639554, 0.001401908609830239, 0.042590093937841474, 0.0011479632468051205  …  0.0011204631426866797, 0.00015613429857250875, 2.947865013621387e-6, 0.00790408313303552, 5.59599327631153e-7, 0.0003592838041831083, 0.04690898258923994, 6.206069842023794e-6, 1.2956930727978817e-10, 0.04756876541960852]
# num_samples: 100
# dimension: 1
# )

# %%
q_w
# Out:
# Gamma{Float64}(α=7.5, θ=0.11876677648331782)

# %%
mean(q_w)
# Out:
# 0.8907508236248837

# %%
sensor_inputs
# Out:
# 5-element Array{Float64,1}:
#  -2.6194642380274464
#   3.8963594155784795
#   5.285301805734398
#  15.91883124081416
#   5.206641841409554

# %%
mean(q_x[1])
# Out:
# -4.541053371060911

# %%
var(q_x[1])
# Out:
# 0.8514240066934036

# %%
x_ax = collect(-20:0.01:20)
plot(x_ax,pdf.(Normal(mean(q_x[1]),sqrt(var(q_x[1]))),x_ax))
scatter!((sensor_inputs[1],0))

# %%
x_ax = collect(-20:0.01:20)
plot(x_ax,pdf.(Normal(mean(q_x[2]),sqrt(var(q_x[2]))),x_ax))
scatter!((sensor_inputs[2],0))

# %%
x_ax = collect(-20:0.01:20)
plot(x_ax,pdf.(Normal(mean(q_x[3]),sqrt(var(q_x[3]))),x_ax))
scatter!((sensor_inputs[3],0))

# %%
x_ax = collect(-20:0.01:20)
plot(x_ax,pdf.(Normal(mean(q_x[4]),sqrt(var(q_x[4]))),x_ax))
scatter!((sensor_inputs[4],0))

# %%
x_ax = collect(-20:0.01:20)
plot(x_ax,pdf.(Normal(mean(q_x[5]),sqrt(var(q_x[5]))),x_ax))
scatter!((sensor_inputs[5],0))
